# %%
####import the basic pakges
import pandas as pd
import numpy as np

# %%
### import the data
cl_data= pd.read_csv("D:\\4 Aug 2020\\Loan prediction\\cleaned data.csv")

# %%
cl_data.head()
# Out:
#    Unnamed: 0 Gender Married Dependents     Education Self_Employed  \
# 0           0   Male      No          0      Graduate            No
# 1           1   Male     Yes          1      Graduate            No
# 2           2   Male     Yes          0      Graduate           Yes
# 3           3   Male     Yes          0  Not Graduate            No
# 4           4   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cl_data.drop(['Unnamed: 0'],inplace=True,axis=1)

# %%
cl_data.head(4)
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y

# %%
#### EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### One- dimentional plot

# %%
### for categorical columns

# %%
sns.countplot('Gender',data=cl_data)
plt.title('Gender')
plt.show()
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('Married',data=cl_data)
plt.title('Married')
plt.show()
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('Dependents',data=cl_data)
plt.title('Dependents')
plt.show()
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('Education',data=cl_data)
plt.title('Education')
plt.show()
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('Self_Employed',data=cl_data)
plt.title('Self_Employed')
plt.show()
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('Credit_History',data=cl_data)
plt.title('Credit_History')
plt.show()
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('Property_Area',data=cl_data)
plt.title('Property_Area')
plt.show()
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('Loan_Status',data=cl_data)
plt.title('Loan_Status')
plt.show()
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#### For numerical column

# %%
sns.histplot(cl_data['ApplicantIncome'])
plt.title('ApplicantIncome')
# Out:
# Text(0.5, 1.0, 'ApplicantIncome')

# %%
sns.histplot(cl_data['CoapplicantIncome'])
plt.title('CoapplicantIncome')
# Out:
# Text(0.5, 1.0, 'CoapplicantIncome')

# %%
sns.histplot(cl_data['LoanAmount'])
plt.title('LoanAmount')
# Out:
# Text(0.5, 1.0, 'LoanAmount')

# %%
sns.countplot(cl_data['Loan_Amount_Term'])
plt.title('Loan_Amount_Term')
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Loan_Amount_Term')

# %% [raw]
# #### Two dimensional data
#
# Here we check the relation between target variable and features.Our target variable is 'Loan _status'

# %%
#### ctegorical and numerical

# %%
sns.swarmplot(x='Loan_Status',y='ApplicantIncome',data=cl_data)
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 64.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 42.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Loan_Status', ylabel='ApplicantIncome'>

# %%
sns.swarmplot(x='Loan_Status',y='CoapplicantIncome',data=cl_data)
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 45.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Loan_Status', ylabel='CoapplicantIncome'>

# %%
sns.swarmplot(x='Loan_Status',y='LoanAmount',data=cl_data)
# Out:
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\sunil\.conda\envs\lpred\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Loan_Status', ylabel='LoanAmount'>

# %%
#### categorical and categorical

# %%
sns.countplot(x='Loan_Status',hue='Gender',data=cl_data)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x='Loan_Status',hue='Married',data=cl_data)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x='Loan_Status',hue='Dependents',data=cl_data)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x='Loan_Status',hue='Education',data=cl_data)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x='Loan_Status',hue='Self_Employed',data=cl_data)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x='Loan_Status',hue='Loan_Amount_Term',data=cl_data)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x='Loan_Status',hue='Credit_History',data=cl_data)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x='Loan_Status',hue='Property_Area',data=cl_data)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>
